# %%
import pandas as pd
df= pd.read_csv('/Users/dennysurdiales/Desktop/Data Homework/CitiBikeResources/JC-202301-citibike-tripdata.csv')
df_2= pd.read_csv('/Users/dennysurdiales/Desktop/Data Homework/CitiBikeResources/JC-202302-citibike-tripdata.csv')
df_3= pd.read_csv('/Users/dennysurdiales/Desktop/Data Homework/CitiBikeResources/JC-202303-citibike-tripdata.csv')

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10  2023-01-28 09:28:52
# 1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12  2023-01-23 20:18:27
# 2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04  2023-01-29 15:32:38
# 3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08  2023-01-24 18:42:13
# 4  323165780CA0734B   classic_bike  2023-01-21 20:44:09  2023-01-21 20:48:08
#
#                          start_station_name start_station_id  \
# 0  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 1  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 2  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 3  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 4                             Hamilton Park            JC009
#
#                              end_station_name end_station_id  start_lat  \
# ...

# %%
df_2.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  557150C42CBD584B  classic_bike  2023-02-16 18:05:38  2023-02-16 18:13:47
# 1  9F1B2C0BCD476C66  classic_bike  2023-02-15 19:20:33  2023-02-15 19:27:06
# 2  4A4A29A7C1B54278  classic_bike  2023-02-18 14:58:16  2023-02-18 15:06:15
# 3  BBF4E1D39D41D78C  classic_bike  2023-02-24 15:16:12  2023-02-24 15:24:17
# 4  3CECAA17C4ABBF30  classic_bike  2023-02-16 18:05:02  2023-02-16 18:05:04
#
#                        start_station_name start_station_id  \
# 0  Mama Johnson Field - 4 St & Jackson St            HB404
# 1  Mama Johnson Field - 4 St & Jackson St            HB404
# 2  Mama Johnson Field - 4 St & Jackson St            HB404
# 3  Mama Johnson Field - 4 St & Jackson St            HB404
# 4  Mama Johnson Field - 4 St & Jackson St            HB404
#
#                                end_station_name end_station_id  start_lat  \
# 0  South Waterfront Walkway - Sinatra Dr & 1 St          HB103  40.743190
# ...

# %%
df_3.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  38F943EA06A4E54F  electric_bike  2023-03-25 09:20:57  2023-03-25 09:32:10
# 1  C76EFC4C3B771E88  electric_bike  2023-03-15 07:55:41  2023-03-15 08:07:44
# 2  02C7BC83975952E6  electric_bike  2023-03-20 08:50:11  2023-03-20 09:00:37
# 3  DB0FB572E0AA9C36  electric_bike  2023-03-02 10:17:07  2023-03-02 10:27:22
# 4  A238B2BDD1072D52  electric_bike  2023-03-04 09:13:23  2023-03-04 09:25:30
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0    Jersey & 6th St            JC027     Glenwood Ave          JC094
# 1    Jersey & 6th St            JC027     Glenwood Ave          JC094
# 2    Jersey & 6th St            JC027     Glenwood Ave          JC094
# 3    Jersey & 6th St            JC027     Glenwood Ave          JC094
# 4    Jersey & 6th St            JC027     Glenwood Ave          JC094
#
#    start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
combined_df= pd.concat([df, df_2, df_3])

# %%
combined_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      0905B18B365C9D20   classic_bike  2023-01-28 09:18:10
# 1      B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12
# 2      5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04
# 3      E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08
# 4      323165780CA0734B   classic_bike  2023-01-21 20:44:09
# ...                 ...            ...                  ...
# 63067  BF0032DA4A305161   classic_bike  2023-03-19 16:25:24
# 63068  32172F9BEF8D56A2   classic_bike  2023-03-22 16:14:15
# 63069  6FCF0C7C1E254341  electric_bike  2023-03-19 02:16:02
# 63070  34DFBEB02424B55E  electric_bike  2023-03-30 20:09:24
# 63071  A235AD010540ACA2   classic_bike  2023-03-17 17:53:28
#
#                   ended_at                        start_station_name  \
# 0      2023-01-28 09:28:52  Hoboken Terminal - Hudson St & Hudson Pl
# 1      2023-01-23 20:18:27  Hoboken Terminal - Hudson St & Hudson Pl
# ...

# %%
combined_df.reset_index(drop=True, inplace=True)

# %%
combined_df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1                236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2                384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3               1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4               5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
# ...              ...                       ...                       ...
# 127181          1054  2020-10-31 23:32:22.8650  2020-10-31 23:49:57.5320
# 127182           156  2020-10-31 23:33:22.7310  2020-10-31 23:35:59.4930
# 127183          1858  2020-10-31 23:37:01.7010  2020-11-01 00:07:59.7530
# 127184          1809  2020-10-31 23:37:46.1430  2020-11-01 00:07:55.2740
# 127185           395  2020-10-31 23:40:06.3530  2020-10-31 23:46:42.0640
#
#         start station id start station name  start station latitude  \
# ...

# %%
output_folder = '/Users/dennysurdiales/Desktop/Data Homework/CitiBikeResources'
output_filename= 'combined_df.csv'
output_path = f"{output_folder}/{output_filename}"

# Save the combined DataFrame to the new CSV file
combined_df.to_csv(output_path, index=False)  # Setting index=False avoids saving the index column
